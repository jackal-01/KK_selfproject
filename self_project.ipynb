# %%
# !pip install numpy
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib
# !pip install sklearn
# Out:
# Requirement already satisfied: numpy in c:\users\kanika\pythongo\python\python37\lib\site-packages (1.21.6)
# Requirement already satisfied: pandas in c:\users\kanika\pythongo\python\python37\lib\site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from pandas) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\kanika\pythongo\python\python37\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from seaborn) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: typing-extensions in c:\users\kanika\pythongo\python\python37\lib\site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn) (4.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\kanika\pythongo\python\python37\lib\site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: typing-extensions in c:\users\kanika\pythongo\python\python37\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (4.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sklearn in c:\users\kanika\pythongo\python\python37\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\kanika\pythongo\python\python37\lib\site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\kanika\pythongo\python\python37\lib\site-packages (from scikit-learn->sklearn) (1.21.6)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %matplotlib inline

# %%
df=pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
sns.jointplot(df['scaled_amount'],df['Class'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\kanika\pythongo\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\kanika\pythongo\python\python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\kanika\pythongo\python\python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'scaled_amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7392\930469213.py in <module>
# ----> 1 sns.jointplot(df['scaled_amount'],df['Class'])
#
# c:\users\kanika\pythongo\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\users\kanika\pythongo\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'scaled_amount'

# %%
rbs = RobustScaler()

df_small = df[['Time','Amount']]
df_small = pd.DataFrame(rbs.fit_transform(df_small))

df_small.columns = ['scaled_time','scaled_amount']
df = pd.concat([df,df_small],axis=1)

df.drop(['Time','Amount'],axis=1,inplace=True)

df.head()

# %%
rbs = RobustScaler()

df_small = df[['Time','Amount']]
df_small = pd.DataFrame(rbs.fit_transform(df_small))
df_small.columns = ['scaled_time','scaled_amount']
df = pd.concat([df,df_small],axis=1)
df.drop(['Time','Amount'],axis=1,inplace=True)
df.head()

# %%
rbs = RobustScaler()

df_small = df[['Time','Amount']]
df_small = pd.DataFrame(rbs.fit_transform(df_small))
df_small.columns = ['scaled_time','scaled_amount']
df = pd.concat([df,df_small],axis=1)
df.drop(['Time','Amount'],axis=1,inplace=True)
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Class  scaled_time  scaled_amount
# 0 -0.189115  0.133558 -0.021053      0    -0.994983       1.783274
# 1  0.125895 -0.008983  0.014724      0    -0.994983      -0.269825
# 2 -0.139097 -0.055353 -0.059752      0    -0.994972       4.983721
# 3 -0.221929  0.062723  0.061458      0    -0.994972       1.418291
# 4  0.502292  0.219422  0.215153      0    -0.994960       0.670579
#
# [5 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
sns.countplot(df['Class'])
# Out:
# c:\users\kanika\pythongo\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
non_fraud = df[df['Class']==0]
fraud = df[df['Class']==1]

non_fraud = non_fraud.sample(frac=1)

non_fraud = non_fraud[:492]

new_df = pd.concat([non_fraud,fraud])
new_df = new_df.sample(frac=1)
new_df.head()
# Out:
#               V1        V2        V3        V4        V5        V6         V7  \
# 42549  -5.314173  4.145944 -8.532522  8.344392 -5.718008 -3.043536 -10.989185
# 222133 -3.613850 -0.922136 -4.749887  3.373001 -0.545207 -1.171301  -4.172315
# 43284  -0.587477  0.288221  1.676481 -0.726303 -0.359868 -0.476161   0.465510
# 8617    0.919137  4.199633 -7.535607  7.426940  1.118215 -2.886722  -1.341036
# 46998  -1.109646  0.811069 -1.138135  0.935265 -2.330248 -0.116106  -1.621986
#
#               V8        V9        V10  ...       V22       V23       V24  \
# 42549   3.404129 -6.167234 -11.435624  ...  0.862996 -0.614453  0.523648
# 222133  1.517016 -1.775833  -3.754054  ...  0.893065  1.034907  0.097671
# 43284   0.048608 -1.723997   0.267413  ... -0.495787  0.015071  0.230231
# 8617    0.363933 -2.203224  -4.137840  ...  0.055179  0.210692 -0.417918
# 46998   0.458028 -0.912189  -2.961996  ...  0.841755  0.176728  0.081004
#
#              V25       V26       V27       V28  Class  scaled_time  \
# 42549  -0.712593  0.324638  2.245091  0.497321      1    -0.511578
# 222133 -1.345551 -0.788329  1.055442  0.099971      1     0.683138
# 43284  -0.137053 -0.655934  0.110200  0.125219      0    -0.508077
# 8617   -0.911188  0.466524  0.627393  0.157851      1    -0.858293
# 46998  -0.258899  0.707654  0.418649  0.080756      1    -0.489479
#
#         scaled_amount
# 42549        0.925452
# 222133       1.715923
# 43284        0.391113
# 8617        -0.293440
# 46998        2.546915
#
# [5 rows x 31 columns]

# %%
new_df['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
sns.countplot(new_df['Class'])
# Out:
# c:\users\kanika\pythongo\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
X = new_df.drop('Class',axis=1)
y = new_df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train,y_train)

pred = lr.predict(X_test)

print(classification_report(y_test,pred))
print('\n\n')
print(confusion_matrix(y_test,pred))
print('\n')
print('accuracy is --> ',round(accuracy_score(y_test,pred)*100,2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93        95
#            1       0.96      0.90      0.93       102
#
#     accuracy                           0.93       197
#    macro avg       0.93      0.93      0.93       197
# weighted avg       0.93      0.93      0.93       197
#
#
#
#
# [[91  4]
#  [10 92]]
#
#
# accuracy is -->  92.89
